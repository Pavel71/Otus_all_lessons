# %% [markdown]
# ## ПОдзадача!
#     1. Нужно определится как будет выглядить моя таблица где будет обучатся модель
#     2. Понять как получать данные для обуения в эту таблицу
#
#     Первая идея какая, будет словарь по которому программа будет пробигатся и выдергивать нужные значения, дальше эти данные будут преобразовыватся и сетится в модель. Тоесть предикт будет делатся на 3-х основных пунктах.
#
#     1. Гликемический индекс(Sum)
#     2. Белки, жиры, углеводы (Sum)
#     3. Ккал(Sum)
#     4. Текущий сахар
#     5. Время укола(Утро,День,Полдник, Вечер)
#     6. Вес, Рост, Возраст, Стаж
#     7. Температура(Болезнь)
#     8. Дополнительная физическая нагрузка после приема пищи

# %%
# Итак пропишу функции заглушки и укажу что хочу в них видит и получчить

# %%
class Product:
    
    def __init__():
        

    def product_data(list_prod):

        """
        Функция принимает данные - Это то какие продукты и в каком кол-ве будет употребленно
        Пример: {Бананы: 150гр., Хлеб: 20гр.} словарь продуктов и их массу

        Дальше мы запрашиваем точные данне по содержанию колорий белков углводов  и тд. 
        за этот прием пищи. и возвращам словарь с суммамим этих данных


        """

        pass


    def get_product(list_prod[0]):
        '''
        Функия принимает 1 конкретный продукт с массой и возвращает его кол-во колорий и других
        данных


        '''

        pass

    def summ_prod({'Kall:120' и тд.}):
        '''
        Функция принимаем чистые данные по каждому продукту и суммирует числа 
        Возвращает Словарь с суммами по всем продуктам за прием пищи

        '''

# %%
# Сахар мы возмем из inpt

# %%
def time_injection(date):
    '''
    Функция принимает текущее время ввода данных
    возвращает Категориальный признак Утро День Полдник Вечер
    
    
    '''
    pass

# %%
def parametr_object(weight = deffult, height = deffult, age = deffult, stage = deffult, 
                   temperature_body = deffult, dop_exercise = deffult):
    
    '''
    Функция принимат параметры человека Которе могут повлиять на эффективность усвоения инсулина
    Задача состоит в том чтобы обновлять такие араметры как стаж, возраст с теением времени
    Остаьные параметры изменть если постуают новые данные
    
    '''
    pass

# %%
# Впринципе для первой программы этих функций должно хватить! Они охватываю большинство признаков
# которые могут повлиять на компенсацию сахара в крови.

# %%
# Поработаю по конкретнеей над этим блоком
# Класс должен обращатся к словарю с данными по продуктам!
# Нужно написать скрипт которые спарсит таблиу с продуктами и ихними данными
# Дальше нужно учесть что каких - то продуктов там нет тоесть нуен скрипт который либо добавит 
# продукт в базу либо обновитпараметры текущего продукта

# Также нужно продумать что если мы не знаем сколько углеводов в продукте
# Например супп какой-нибудь Как тогда быть: нужно как то в среднем указать на суп 0.5 - 1
# Пока самая проблема именно в сппах в остальном можно работать!


def parsing_product_tebale():
    
    '''
    Функция парсит таблицу с продуктами с сайта и преобразует текщие данные в DataFrame
    
    '''
    
    
    pass
def change_add_prouct():
    
    '''
    Функция вносит новые продкты в таблицу или изменяет параметры продуктов согласно 
    текущим данным
    
    Тоесть нужно сделать так чтобы если данне вводятся Скажем Бананы: 150гр., углеводы: 25гр.
    
    То в расчете мы используем в банаах углвод равные 25 а не деффолтные и вообще заменем 
    дефолтные углеводы на текущие
    
    '''
    
    pass

class Product:
    
    def __init__():
        

    def product_data(list_prod):

        """
        Функция принимает данные - Это то какие продукты и в каком кол-ве будет употребленно
        Пример: {Бананы: 150гр., Хлеб: 20гр.} словарь продуктов и их массу

        Дальше мы запрашиваем точные данне по содержанию колорий белков углводов  и тд. 
        за этот прием пищи. и возвращам словарь с суммамим этих данных


        """

        pass


    def get_product(list_prod[0]):
        '''
        Функия принимает 1 конкретный продукт с массой и возвращает его кол-во колорий и других
        данных


        '''

        pass

    def summ_prod({'Kall:120' и тд.}):
        '''
        Функция принимаем чистые данные по каждому продукту и суммирует числа 
        Возвращает Словарь с суммами по всем продуктам за прием пищи

        '''

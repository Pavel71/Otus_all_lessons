# %% [markdown]
# <img src='otus.png'>
#
# # Лекция 22: "Нейронные сети, часть 1"
#
# План лекции:
#
# 1. Вычислительные графы. Библиотека Pytorch и ее отличия от Tensorflow.
# 2. Пример: линейная регрессия.
# 3. Нейронные сети: базовые понятия.
# 4. Пример: логистическая регрессия, полносвязная нейронная сеть.
# 5. Метод обратного распространения ошибки.
#
# Если у вас появился существенный для понимания вопрос, пишите "111" в чат.

# %%
# %matplotlib inline

# %% [markdown]
# ## 1. Pytorch

# %% [markdown]
# ### Граф вычислений и дифференцирование
#
# Рассмотрим функцию $$x^2 + xy + (x + y)^2$$
#
# Ее можно представить в виде графа несколькими способами (как композицию простых функций):
#
# <img src='graph.png'>

# %% [markdown]
# См. ноутбук "pytorch_tutorial.ipynb".

# %% [markdown]
# ## 2. Линейная регрессия

# %% [markdown]
# ### 2а. Подготовка данных

# %%
import torch
import matplotlib.pyplot as plt
true_slope, true_bias = 2., 1.
n_samples = 100

x = torch.rand(n_samples, 1)
y = true_slope * x + true_bias + 0.1 * torch.randn(n_samples, 1)

# %%
plt.scatter(x, y)
plt.show()

# %% [markdown]
# ### 2б. Аналитическое решение

# %% [markdown]
# *Напоминание.*
#
# В случае квадратичной функции потерь можно выписать простое аналитическое выражение для коэффициентов линейной регрессии:
#
# $$\theta =  (X^T X)^{-1}X^T Y$$
#
# Здесь $X$ это матрица признаков ($N \times d$), а $Y$ это вектор-столбец ($N \times 1$) наблюдений целевой переменной.
#
# Последняя компонента $X$ равна 1 (просто соглашение), для того чтобы избавиться в формулах от "сдвига". Например,
# $$y=2x_1 + 4x_2+3$$
# Можно записать двумя разными способами:
# 1. $y=\theta^T x = (2, 4, 3)\cdot(x_1, x_2, 1)$
# 2. $y=\theta^T x + b = (2, 4)\cdot(x_1, x_2) + 3$
#
# Далее пользуемся первым способом.

# %%
ones = torch.ones(n_samples, 1)
x_ones = torch.cat((x, ones), dim=1)  # concatenated with ones
x_ones_t = torch.t(x_ones) # transposed

theta = torch.inverse(x_ones_t.mm(x_ones)).mm(x_ones_t).mm(y)

print('slope: {}, bias: {}'.format(*theta.numpy()))
# Out:
# slope: [1.9969256], bias: [0.98796606]

# %%
line[0].numpy()
# Out:
# array([0., 1.], dtype=float32)

# %%
values
# Out:
# tensor([[ 0.9880],
#         [ 2.9849]])

# %%
# trained model
line = torch.tensor([[0, 1.],[1., 1.]])
values = torch.mm(line, theta)
plt.plot(line[0].numpy(), values.numpy(), color='red')
plt.scatter(x, y)
plt.show()

# %% [markdown]
# ### 2в. Решение с помощью оптимизации функции потерь

# %%
from torch.autograd import Variable

# %%
w = torch.randn(2, 1, requires_grad=True)           # параметры theta, инициализированные случайно

# %%
num_steps = 1000
learning_rate = 0.1
losses = []
for i in range(num_steps):
    y_pred = x_ones.mm(w)
    loss = (y - y_pred).pow(2).mean(dim=0)
    losses.append(float(loss.data))
    loss.backward()
    with torch.no_grad():
        w -= learning_rate * w.grad
        w.grad.zero_()

# %%
plt.plot(losses)
plt.show()
print('final loss: {:.3f}'.format(losses[-1]))
# Out:
# final loss: 0.011

# %%
# trained model
line = torch.tensor([[0, 1.],[1., 1.]])
values = torch.mm(line, w)
plt.plot(line[0].numpy(), values.data.numpy(), color='red')
plt.scatter(x, y)
plt.show()

# %% [markdown]
# ## 3. Нейронные сети: базовые определения
#
# См. презентацию.
#
# Полносвязная сеть ($A$ - входы, размер $N \times d$):
#
#
# $$L_1 = f_1(W_1 A+b_1)$$
# $$L_2 = f_2(W_2 L_1+b_2)$$
# $$OUT = f_3(W_3 L_2+b_3)$$

# %% [markdown]
# ## 4. Логистическая регрессия

# %% [markdown]
# ### 4б. Подготовка данных

# %%
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
import pandas as pd
from sklearn import datasets
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LinearRegression
from pandas.tools.plotting import table
from sklearn import datasets
from sklearn.model_selection import train_test_split

# %matplotlib inline
plt.rcParams["figure.figsize"] = [12, 8]

np.random.seed(84)

# %%
X, y = datasets.make_classification(n_features=2, n_informative=2, n_redundant=0, n_repeated=0, random_state=12, n_samples=130)
x = np.c_[np.ones((X.shape[0], 1)), X]
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=30, random_state=42)

colors = ['yellow' if y_i else 'blue' for y_i in y_train]
plt.scatter(x_train[:, 1], x_train[:, 2], c=colors)
plt.title("Classification problem \n What is the color for the new (x1, x2) pair?")
plt.xlabel("x1 (feature)")
plt.ylabel("x2 (feature)")
plt.show()

print(X.shape, y.shape)
# Out:
# (130, 2) (130,)

# %% [markdown]
# ## 4б. Логистическая регрессия
#
# Для линейной регрессии мы написали "наивный" алгоритм, сейчас время воспользоваться полезными абстракциями, который предлагает Pytorch:
#
# * Модульность (nn)
# * Оптимизаторы (optim)
#
# Внимание: это упрощенная и наглядная версия, в реальности лучше рассчитывать логиты (logits) и по ним уже считать значение функции потерь. Численно это более устойчивый вариант.

# %%
import torch.nn as nn

learning_rate = 1e-2

# %%
def make_grid(x_min=-1, x_max=1, y_min=-1, y_max=1, step_x=0.1, step_y=0.1):
    x_grid, y_grid = np.meshgrid(np.arange(x_min, x_max, step_x), np.arange(y_min, y_max, step_y))
    pos = np.empty(x_grid.shape + (2,))
    pos[:, :, 0] = x_grid
    pos[:, :, 1] = y_grid
    pos_lin = pos.reshape(pos.shape[0] * pos.shape[1], 2)
    return pos_lin, x_grid, y_grid

# %%
class LogisticRegression(nn.Module):
    def __init__(self, inp_size=3, out_size=1):
        """
        Определим одно линейное преобразование при инициализации.
        """
        super(LogisticRegression, self).__init__()
        self.linear = nn.Linear(inp_size, out_size)
        self.sigm = nn.Sigmoid()

    def forward(self, x):
        """
        Метод "forward" принимает на вход тензор с данными и возвращает результат расчета.
        """
        out = self.sigm(self.linear(x))
        return out

# %%
model = LogisticRegression()
criterion = nn.BCELoss()
opt = torch.optim.SGD(model.parameters(), lr=learning_rate)

# %%
# visualize decision boundary -- before training
grid, xm, ym = make_grid(-5, 5, -5, 5)
out = model(torch.cat((torch.ones(grid.shape[0], 1), torch.tensor(grid.astype(np.float32))), dim=1))
plt.contourf(xm, ym, out.data.numpy().reshape(xm.shape), 10, cmap='Reds', origin='lower', alpha=0.5)
plt.contour(xm, ym, out.data.numpy().reshape(xm.shape), levels=[0.5])
plt.scatter(x_train[:, 1], x_train[:, 2], c=colors)
plt.plot()
# Out:
# []

# %%
x = torch.tensor(x_train.astype(np.float32))
y = torch.tensor(y_train.reshape((-1, 1)).astype(np.float32))
losses = []
for t in range(1000):
    # расчет предсказания модели
    y_pred = model(torch.tensor(x))

    # расчет функции потерь
    loss = criterion(y_pred, y)
    print('step: {}; training loss: {:.3f}'.format(t, loss.item()))
    losses.append(loss.item())

    # обнулить градиенты, рассчитать новые градиенты, обновить веса
    opt.zero_grad()
    loss.backward()
    opt.step()
# Out:
# step: 0; training loss: 0.513
# step: 1; training loss: 0.512
# step: 2; training loss: 0.512
# step: 3; training loss: 0.511
# step: 4; training loss: 0.511
# step: 5; training loss: 0.510
# step: 6; training loss: 0.510
# step: 7; training loss: 0.509
# step: 8; training loss: 0.509
# step: 9; training loss: 0.508
# step: 10; training loss: 0.508
# step: 11; training loss: 0.507
# step: 12; training loss: 0.507
# step: 13; training loss: 0.506
# step: 14; training loss: 0.506
# step: 15; training loss: 0.506
# step: 16; training loss: 0.505
# step: 17; training loss: 0.505
# step: 18; training loss: 0.504
# step: 19; training loss: 0.504
# step: 20; training loss: 0.503
# step: 21; training loss: 0.503
# step: 22; training loss: 0.503
# step: 23; training loss: 0.502
# step: 24; training loss: 0.502
# step: 25; training loss: 0.501
# step: 26; training loss: 0.501
# step: 27; training loss: 0.500
# step: 28; training loss: 0.500
# step: 29; training loss: 0.500
# step: 30; training loss: 0.499
# step: 31; training loss: 0.499
# step: 32; training loss: 0.498
# step: 33; training loss: 0.498
# step: 34; training loss: 0.498
# step: 35; training loss: 0.497
# step: 36; training loss: 0.497
# step: 37; training loss: 0.496
# step: 38; training loss: 0.496
# step: 39; training loss: 0.496
# step: 40; training loss: 0.495
# step: 41; training loss: 0.495
# step: 42; training loss: 0.495
# step: 43; training loss: 0.494
# step: 44; training loss: 0.494
# step: 45; training loss: 0.493
# step: 46; training loss: 0.493
# step: 47; training loss: 0.493
# step: 48; training loss: 0.492
# step: 49; training loss: 0.492
# step: 50; training loss: 0.492
# step: 51; training loss: 0.491
# step: 52; training loss: 0.491
# step: 53; training loss: 0.491
# step: 54; training loss: 0.490
# step: 55; training loss: 0.490
# step: 56; training loss: 0.490
# step: 57; training loss: 0.489
# step: 58; training loss: 0.489
# step: 59; training loss: 0.489
# step: 60; training loss: 0.488
# step: 61; training loss: 0.488
# step: 62; training loss: 0.488
# step: 63; training loss: 0.487
# step: 64; training loss: 0.487
# step: 65; training loss: 0.487
# step: 66; training loss: 0.486
# step: 67; training loss: 0.486
# step: 68; training loss: 0.486
# step: 69; training loss: 0.485
# step: 70; training loss: 0.485
# step: 71; training loss: 0.485
# step: 72; training loss: 0.484
# step: 73; training loss: 0.484
# step: 74; training loss: 0.484
# step: 75; training loss: 0.484
# step: 76; training loss: 0.483
# step: 77; training loss: 0.483
# step: 78; training loss: 0.483
# step: 79; training loss: 0.482
# step: 80; training loss: 0.482
# step: 81; training loss: 0.482
# step: 82; training loss: 0.481
# step: 83; training loss: 0.481
# step: 84; training loss: 0.481
# step: 85; training loss: 0.481
# step: 86; training loss: 0.480
# step: 87; training loss: 0.480
# step: 88; training loss: 0.480
# step: 89; training loss: 0.479
# step: 605; training loss: 0.431
# step: 606; training loss: 0.431
# step: 607; training loss: 0.431
# step: 608; training loss: 0.431
# step: 609; training loss: 0.431
# step: 610; training loss: 0.431
# step: 611; training loss: 0.431
# step: 612; training loss: 0.431
# step: 613; training loss: 0.431
# step: 614; training loss: 0.431
# step: 615; training loss: 0.431
# step: 616; training loss: 0.431
# step: 617; training loss: 0.431
# step: 618; training loss: 0.431
# step: 619; training loss: 0.431
# step: 620; training loss: 0.431
# step: 621; training loss: 0.431
# step: 622; training loss: 0.431
# step: 623; training loss: 0.431
# step: 624; training loss: 0.431
# step: 625; training loss: 0.430
# step: 626; training loss: 0.430
# step: 627; training loss: 0.430
# step: 628; training loss: 0.430
# step: 629; training loss: 0.430
# step: 630; training loss: 0.430
# step: 631; training loss: 0.430
# step: 632; training loss: 0.430
# step: 633; training loss: 0.430
# step: 634; training loss: 0.430
# step: 635; training loss: 0.430
# step: 636; training loss: 0.430
# step: 637; training loss: 0.430
# step: 638; training loss: 0.430
# step: 639; training loss: 0.430
# step: 640; training loss: 0.430
# step: 641; training loss: 0.430
# step: 642; training loss: 0.430
# step: 643; training loss: 0.430
# step: 644; training loss: 0.430
# step: 645; training loss: 0.430
# step: 646; training loss: 0.430
# step: 647; training loss: 0.430
# step: 648; training loss: 0.430
# step: 649; training loss: 0.430
# step: 650; training loss: 0.430
# step: 651; training loss: 0.430
# step: 652; training loss: 0.430
# step: 653; training loss: 0.430
# step: 654; training loss: 0.430
# step: 655; training loss: 0.430
# step: 656; training loss: 0.430
# step: 657; training loss: 0.430
# step: 658; training loss: 0.430
# step: 659; training loss: 0.430
# step: 660; training loss: 0.430
# step: 661; training loss: 0.430
# step: 662; training loss: 0.430
# step: 663; training loss: 0.430
# step: 664; training loss: 0.430
# step: 665; training loss: 0.430
# step: 666; training loss: 0.430
# step: 667; training loss: 0.430
# step: 668; training loss: 0.430
# step: 669; training loss: 0.430
# step: 670; training loss: 0.430
# step: 671; training loss: 0.430
# step: 672; training loss: 0.430
# step: 673; training loss: 0.430
# step: 674; training loss: 0.429
# step: 675; training loss: 0.429
# step: 676; training loss: 0.429
# step: 677; training loss: 0.429
# step: 678; training loss: 0.429
# step: 679; training loss: 0.429
# step: 680; training loss: 0.429
# step: 681; training loss: 0.429
# step: 682; training loss: 0.429
# step: 683; training loss: 0.429
# step: 684; training loss: 0.429
# step: 685; training loss: 0.429
# step: 686; training loss: 0.429
# step: 687; training loss: 0.429
# step: 688; training loss: 0.429
# step: 689; training loss: 0.429
# step: 690; training loss: 0.429
# step: 691; training loss: 0.429
# step: 692; training loss: 0.429
# step: 693; training loss: 0.429
# step: 694; training loss: 0.429
# step: 695; training loss: 0.429
# step: 696; training loss: 0.429
# step: 697; training loss: 0.429
# step: 698; training loss: 0.429
# step: 699; training loss: 0.429
# step: 700; training loss: 0.429
# step: 701; training loss: 0.429
# step: 702; training loss: 0.429
# step: 703; training loss: 0.429
# step: 704; training loss: 0.429
# step: 705; training loss: 0.429
# step: 706; training loss: 0.429
# step: 707; training loss: 0.429
# step: 708; training loss: 0.429
# step: 709; training loss: 0.429
# step: 710; training loss: 0.429
# step: 711; training loss: 0.429
# step: 712; training loss: 0.429
# step: 713; training loss: 0.429
# step: 714; training loss: 0.429
# step: 715; training loss: 0.429
# step: 716; training loss: 0.429
# step: 717; training loss: 0.429
# step: 718; training loss: 0.429
# step: 719; training loss: 0.429
# step: 720; training loss: 0.429
# step: 721; training loss: 0.429
# step: 722; training loss: 0.429
# step: 723; training loss: 0.429
# step: 724; training loss: 0.429
# step: 725; training loss: 0.429
# step: 726; training loss: 0.429
# step: 727; training loss: 0.429
# step: 728; training loss: 0.429
# step: 729; training loss: 0.429
# step: 730; training loss: 0.429
# step: 731; training loss: 0.429
# step: 732; training loss: 0.429
# step: 733; training loss: 0.428
# step: 734; training loss: 0.428
# step: 735; training loss: 0.428
# step: 736; training loss: 0.428
# step: 737; training loss: 0.428
# step: 738; training loss: 0.428
# step: 739; training loss: 0.428
# step: 740; training loss: 0.428
# step: 741; training loss: 0.428
# step: 742; training loss: 0.428
# step: 743; training loss: 0.428
# step: 744; training loss: 0.428
# step: 745; training loss: 0.428
# step: 746; training loss: 0.428
# step: 747; training loss: 0.428
# step: 748; training loss: 0.428
# step: 749; training loss: 0.428
# step: 750; training loss: 0.428
# step: 751; training loss: 0.428
# step: 752; training loss: 0.428
# step: 753; training loss: 0.428
# step: 754; training loss: 0.428
# step: 755; training loss: 0.428
# step: 756; training loss: 0.428
# step: 757; training loss: 0.428
# step: 758; training loss: 0.428
# step: 759; training loss: 0.428
# step: 760; training loss: 0.428
# step: 761; training loss: 0.428
# step: 762; training loss: 0.428
# step: 763; training loss: 0.428
# step: 764; training loss: 0.428
# step: 765; training loss: 0.428
# step: 766; training loss: 0.428
# step: 767; training loss: 0.428
# step: 768; training loss: 0.428
# step: 769; training loss: 0.428
# step: 770; training loss: 0.428
# step: 771; training loss: 0.428
# step: 772; training loss: 0.428
# step: 773; training loss: 0.428
# step: 774; training loss: 0.428
# step: 775; training loss: 0.428
# step: 776; training loss: 0.428
# step: 777; training loss: 0.428
# step: 778; training loss: 0.428
# step: 779; training loss: 0.428
# step: 780; training loss: 0.428
# step: 781; training loss: 0.428
# step: 782; training loss: 0.428
# step: 783; training loss: 0.428
# step: 784; training loss: 0.428
# step: 785; training loss: 0.428
# step: 786; training loss: 0.428
# step: 787; training loss: 0.428
# step: 788; training loss: 0.428
# step: 789; training loss: 0.428
# step: 790; training loss: 0.428
# step: 791; training loss: 0.428
# step: 792; training loss: 0.428
# step: 793; training loss: 0.428
# step: 794; training loss: 0.428
# step: 795; training loss: 0.428
# step: 796; training loss: 0.428
# step: 797; training loss: 0.428
# step: 798; training loss: 0.428
# step: 799; training loss: 0.428
# step: 800; training loss: 0.428
# step: 801; training loss: 0.428
# step: 802; training loss: 0.428
# step: 803; training loss: 0.428
# step: 804; training loss: 0.428
# step: 805; training loss: 0.428
# step: 806; training loss: 0.428
# step: 807; training loss: 0.428
# step: 808; training loss: 0.427
# step: 809; training loss: 0.427
# step: 810; training loss: 0.427
# step: 811; training loss: 0.427
# step: 915; training loss: 0.426
# step: 916; training loss: 0.426
# step: 917; training loss: 0.426
# step: 918; training loss: 0.426
# step: 919; training loss: 0.426
# step: 920; training loss: 0.426
# step: 921; training loss: 0.426
# step: 922; training loss: 0.426
# step: 923; training loss: 0.426
# step: 924; training loss: 0.426
# step: 925; training loss: 0.426
# step: 926; training loss: 0.426
# step: 927; training loss: 0.426
# step: 928; training loss: 0.426
# step: 929; training loss: 0.426
# step: 930; training loss: 0.426
# step: 931; training loss: 0.426
# step: 932; training loss: 0.426
# step: 933; training loss: 0.426
# step: 934; training loss: 0.426
# step: 935; training loss: 0.426
# step: 936; training loss: 0.426
# step: 937; training loss: 0.426
# step: 938; training loss: 0.426
# step: 939; training loss: 0.426
# step: 940; training loss: 0.426
# step: 941; training loss: 0.426
# step: 942; training loss: 0.426
# step: 943; training loss: 0.426
# step: 944; training loss: 0.426
# step: 945; training loss: 0.426
# step: 946; training loss: 0.426
# step: 947; training loss: 0.426
# step: 948; training loss: 0.426
# step: 949; training loss: 0.426
# step: 950; training loss: 0.426
# step: 951; training loss: 0.426
# step: 952; training loss: 0.426
# step: 953; training loss: 0.426
# step: 954; training loss: 0.426
# step: 955; training loss: 0.426
# step: 956; training loss: 0.426
# step: 957; training loss: 0.426
# step: 958; training loss: 0.426
# step: 959; training loss: 0.426
# step: 960; training loss: 0.426
# step: 961; training loss: 0.426
# step: 962; training loss: 0.426
# step: 963; training loss: 0.426
# step: 964; training loss: 0.426
# step: 965; training loss: 0.426
# step: 966; training loss: 0.426
# step: 967; training loss: 0.426
# step: 968; training loss: 0.426
# step: 969; training loss: 0.426
# step: 970; training loss: 0.426
# step: 971; training loss: 0.426
# step: 972; training loss: 0.426
# step: 973; training loss: 0.426
# step: 974; training loss: 0.426
# step: 975; training loss: 0.426
# step: 976; training loss: 0.426
# step: 977; training loss: 0.426
# step: 978; training loss: 0.426
# step: 979; training loss: 0.426
# step: 980; training loss: 0.426
# step: 981; training loss: 0.426
# step: 982; training loss: 0.426
# step: 983; training loss: 0.426
# step: 984; training loss: 0.426
# step: 985; training loss: 0.426
# step: 986; training loss: 0.426
# step: 987; training loss: 0.426
# step: 988; training loss: 0.426
# step: 989; training loss: 0.426
# step: 990; training loss: 0.426
# step: 991; training loss: 0.426
# step: 992; training loss: 0.426
# step: 993; training loss: 0.426
# step: 994; training loss: 0.426
# step: 995; training loss: 0.426
# step: 996; training loss: 0.426
# step: 997; training loss: 0.426
# step: 998; training loss: 0.426
# step: 999; training loss: 0.426

# %%
plt.plot(losses)
plt.show()
print('final loss: {:.3f}'.format(losses[-1]))
# Out:
# final loss: 0.426

# %%
# visualize decision boundary -- after training
grid, xm, ym = make_grid(-5, 5, -5, 5)
out = model(torch.cat((torch.ones(grid.shape[0], 1), torch.tensor(grid.astype(np.float32))), dim=1))
plt.contourf(xm, ym, out.data.numpy().reshape(xm.shape), 10, cmap='Reds', origin='lower', alpha=0.5)
plt.contour(xm, ym, out.data.numpy().reshape(xm.shape), levels=[0.5])
plt.scatter(x_train[:, 1], x_train[:, 2], c=colors)
plt.plot()
# Out:
# []

# %% [markdown]
# ## 4в. Полносвязная НС
#
# Все абсолютно то же самое. Меняем только модель.
#
# <img src='https://camo.githubusercontent.com/269f47b8185a2ca349ead57db511250553fd918b/687474703a2f2f63733233316e2e6769746875622e696f2f6173736574732f6e6e312f6e657572616c5f6e6574322e6a706567'>

# %%
model = torch.nn.Sequential(
    torch.nn.Linear(3, 20),
    torch.nn.ReLU(),
    torch.nn.Linear(20, 20),
    torch.nn.ReLU(),
    torch.nn.Linear(20, 1),
    torch.nn.Sigmoid()
)

# %%
criterion = nn.BCELoss()
opt = torch.optim.SGD(model.parameters(), lr=learning_rate)

# %%
# visualize decision boundary -- before training
grid, xm, ym = make_grid(-5, 5, -5, 5)
out = model(torch.cat((torch.ones(grid.shape[0], 1), torch.tensor(grid.astype(np.float32))), dim=1))
plt.contourf(xm, ym, out.data.numpy().reshape(xm.shape), 10, cmap='Reds', origin='lower', alpha=0.5)
plt.contour(xm, ym, out.data.numpy().reshape(xm.shape), levels=[0.5])
plt.scatter(x_train[:, 1], x_train[:, 2], c=colors)
plt.plot()
# Out:
# []

# %%
x = torch.tensor(x_train.astype(np.float32))
y = torch.tensor(y_train.reshape((-1, 1)).astype(np.float32))
losses = []
for t in range(1000):
    # расчет предсказания модели
    y_pred = model(torch.tensor(x))

    # расчет функции потерь
    loss = criterion(y_pred, y)
    print('step: {}; training loss: {:.3f}'.format(t, loss.item()))
    losses.append(loss.item())

    # обнулить градиенты, рассчитать новые градиенты, обновить веса
    opt.zero_grad()
    loss.backward()
    opt.step()
# Out:
# step: 0; training loss: 0.639
# step: 1; training loss: 0.638
# step: 2; training loss: 0.638
# step: 3; training loss: 0.637
# step: 4; training loss: 0.637
# step: 5; training loss: 0.636
# step: 6; training loss: 0.636
# step: 7; training loss: 0.635
# step: 8; training loss: 0.635
# step: 9; training loss: 0.634
# step: 10; training loss: 0.634
# step: 11; training loss: 0.633
# step: 12; training loss: 0.633
# step: 13; training loss: 0.632
# step: 14; training loss: 0.632
# step: 15; training loss: 0.631
# step: 16; training loss: 0.631
# step: 17; training loss: 0.630
# step: 18; training loss: 0.630
# step: 19; training loss: 0.630
# step: 20; training loss: 0.629
# step: 21; training loss: 0.629
# step: 22; training loss: 0.628
# step: 23; training loss: 0.628
# step: 24; training loss: 0.627
# step: 25; training loss: 0.627
# step: 26; training loss: 0.626
# step: 27; training loss: 0.626
# step: 28; training loss: 0.625
# step: 29; training loss: 0.624
# step: 30; training loss: 0.624
# step: 31; training loss: 0.623
# step: 32; training loss: 0.623
# step: 33; training loss: 0.622
# step: 34; training loss: 0.622
# step: 35; training loss: 0.621
# step: 36; training loss: 0.621
# step: 37; training loss: 0.620
# step: 38; training loss: 0.620
# step: 39; training loss: 0.619
# step: 40; training loss: 0.619
# step: 41; training loss: 0.618
# step: 42; training loss: 0.618
# step: 43; training loss: 0.617
# step: 44; training loss: 0.617
# step: 45; training loss: 0.616
# step: 46; training loss: 0.616
# step: 47; training loss: 0.615
# step: 48; training loss: 0.615
# step: 49; training loss: 0.614
# step: 50; training loss: 0.614
# step: 979; training loss: 0.348
# step: 980; training loss: 0.348
# step: 981; training loss: 0.348
# step: 982; training loss: 0.348
# step: 983; training loss: 0.348
# step: 984; training loss: 0.348
# step: 985; training loss: 0.347
# step: 986; training loss: 0.347
# step: 987; training loss: 0.347
# step: 988; training loss: 0.347
# step: 989; training loss: 0.347
# step: 990; training loss: 0.347
# step: 991; training loss: 0.347
# step: 992; training loss: 0.347
# step: 993; training loss: 0.347
# step: 994; training loss: 0.347
# step: 995; training loss: 0.347
# step: 996; training loss: 0.347
# step: 997; training loss: 0.347
# step: 998; training loss: 0.347
# step: 999; training loss: 0.347

# %%
plt.plot(losses)
plt.show()
print('final loss: {:.3f}'.format(losses[-1]))
# Out:
# final loss: 0.347

# %%
# visualize decision boundary -- after training
grid, xm, ym = make_grid(-5, 5, -5, 5)
out = model(torch.cat((torch.ones(grid.shape[0], 1), torch.tensor(grid.astype(np.float32))), dim=1))
plt.contourf(xm, ym, out.data.numpy().reshape(xm.shape), 10, cmap='Reds', origin='lower', alpha=0.5)
plt.contour(xm, ym, out.data.numpy().reshape(xm.shape), levels=[0.5])
plt.scatter(x_train[:, 1], x_train[:, 2], c=colors)
plt.plot()
# Out:
# []

# %% [markdown]
# ## Обучение нейронной сети, алгоритм обратного распространения ошибки

# %% [markdown]
# ### Граф вычислений и дифференцирование
#
# Рассмотрим функцию $$x^2 + xy + (x + y)^2$$
#
# Ее можно представить в виде графа несколькими способами (как композицию простых функций):
#
# <img src='graph.png'>
#
# Будем рассматривать граф слева как исходный для вычисления функции.
#
# Дифференцирование. Пользуемся правилом дифференцирования сложной функции.
#
# $$(f\circ g)\prime(x) = (f(g(x)))\prime = f\prime(g(x))g\prime(x)$$
#
# <img src='g1.png'>
#
# Алгоритм: ищем все пути в графе от $f$ к $x$ и суммируем произведения производных для каждого пути.
#
# Разбор примера см в [1]

# %% [markdown]
# ## Виды оптимизаторов

# %% [markdown]
# ## Функции активации
#
# <img src='act.png'>
#
# Логистический сигмоид
#
# $$ \frac{1}{1 + e^{-x}}$$
#
# Гиперболический тангенс tanh
#
# $$\frac{e^x-e^{-x}}{e^x+e^{-x}}$$
#
# Ступенька (функция Хевисайда)
#
# $$\begin{cases}
#     0, & x < 0\\
#     1, & x \geq 0.
#   \end{cases}$$
#
# ReLU
# $$\begin{cases}
#     0, & x < 0\\
#     x, & x \geq 0.
#   \end{cases}$$

# %% [markdown]
# ## Проблема xor

# %% [markdown]
# ![alt text](http://web.science.mq.edu.au/~cassidy/comp449/html/xor.gif)
#
# Здесь можно посмотреть как влияют параметры нейронных сетей на итоговое решение:
# https://goo.gl/LvPGqU

# %% [markdown]
# ### Сравнение фреймворков
#
# * Tensorflow + Keras
# * Pytorch
#
# ====
#
# * mxnet, Caffe, CNTK, Theano

# %% [markdown]
# ## Литература
#
# 1. Николенко, Кадурин, Архангельская. Глубокое обучение. Погружение в мир нейронных сетей.
# 2. Aurélien Géron Hands-on Machine Learning with Scikit-Learn and TensorFlow
# 3. Гудфеллоу, Бенджио, Курвилль. Глубокое обучение
